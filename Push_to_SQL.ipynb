# %%
# Import modules
from bs4 import BeautifulSoup
import requests
from splinter import Browser
from selenium import webdriver
import pandas as pd
import time
from secret import username, password
from sqlalchemy import create_engine

# %% [markdown]
# #### Clean international revenue data set

# %%
master_df = pd.read_csv("Master_Table.csv")

# %%
master_df.head(3)
# Out:
#    Rank              Title  Year   Lifetime Gross  GrossNumeric
# 0     1  Avengers: Endgame  2019  $2,797,800,564     2797800564
# 1     2             Avatar  2009  $2,790,439,000     2790439000
# 2     3            Titanic  1997  $2,195,169,138     2195169138

# %%
len(master_df)
# Out:
# 10200

# %%
# Getting the duplicate movie by title and year released. 
duplicated_master_df = master_df.loc[master_df.duplicated(subset=["Title","Year"]), "Title"].unique()
duplicated_master_df
# Out:
# array(['War of the Buttons', 'My Love'], dtype=object)

# %%
# Get all the data for the duplicate movie 
duplicated_master_df = master_df.loc[master_df["Title"] == "War of the Buttons"]
duplicated_master_df
# Out:
#       Rank               Title  Year Lifetime Gross  GrossNumeric
# 5983  5984  War of the Buttons  2011   $15,082,409       15082409
# 6643  6644  War of the Buttons  2011   $12,326,773       12326773

# %%
# Get all the data for the duplicate movie 
duplicated_master_df = master_df.loc[master_df["Title"] == "My Love"]
duplicated_master_df
# Out:
#       Rank    Title  Year Lifetime Gross  GrossNumeric
# 5334  5335  My Love  2007   $18,525,631       18525631
# 8994  8995  My Love  2007    $6,660,413        6660413

# %%
# reset index
master_df.reset_index()
# Out:
#        index   Rank                                       Title  Year  \
# 0          0      1                           Avengers: Endgame  2019
# 1          1      2                                      Avatar  2009
# 2          2      3                                     Titanic  1997
# 3          3      4  Star Wars: Episode VII - The Force Awakens  2015
# 4          4      5                      Avengers: Infinity War  2018
# ...      ...    ...                                         ...   ...
# 10195  10195  10196                              Swiss Army Man  2016
# 10196  10196  10197                                   Mes héros  2012
# 10197  10197  10198                       Nymphomaniac: Vol. II  2014
# 10198  10198  10199                             The Hairdresser  2010
# 10199  10199  10200               Sgt. Stubby: An American Hero  2018
#
#         Lifetime Gross  GrossNumeric
# 0      $2,797,800,564     2797800564
# 1      $2,790,439,000     2790439000
# 2      $2,195,169,138     2195169138
# 3      $2,068,223,624     2068223624
# 4      $2,048,359,754     2048359754
# ...                ...           ...
# 10195      $4,935,501        4935501
# 10196      $4,934,927        4934927
# 10197      $4,934,725        4934725
# 10198      $4,934,394        4934394
# 10199      $4,932,694        4932694
#
# [10200 rows x 6 columns]

# %%
# Drop row by index
clean_df = master_df.drop(index=master_df.index[[6643, 8994]])

# %%
len(clean_df)
# Out:
# 10198

# %%
# Select columns
clean_df = clean_df[['Rank', 'Title', 'Year', 'GrossNumeric']]

# %%
clean_df.head()
# Out:
#    Rank                                       Title  Year  GrossNumeric
# 0     1                           Avengers: Endgame  2019    2797800564
# 1     2                                      Avatar  2009    2790439000
# 2     3                                     Titanic  1997    2195169138
# 3     4  Star Wars: Episode VII - The Force Awakens  2015    2068223624
# 4     5                      Avengers: Infinity War  2018    2048359754

# %%
# Rename columns
international_v2 = clean_df.rename(columns={'Rank': 'rank', 'Title': 'name_international', 'Year': 'year', 'GrossNumeric': 'international_revenue_usd'})

# %%
international_v2.head()
# Out:
#    rank                          name_international  year  \
# 0     1                           Avengers: Endgame  2019
# 1     2                                      Avatar  2009
# 2     3                                     Titanic  1997
# 3     4  Star Wars: Episode VII - The Force Awakens  2015
# 4     5                      Avengers: Infinity War  2018
#
#    international_revenue_usd
# 0                 2797800564
# 1                 2790439000
# 2                 2195169138
# 3                 2068223624
# 4                 2048359754

# %%
international_v2.set_index('rank', inplace=True)

# %%
international_v2.head()
# Out:
#                               name_international  year  \
# rank
# 1                              Avengers: Endgame  2019
# 2                                         Avatar  2009
# 3                                        Titanic  1997
# 4     Star Wars: Episode VII - The Force Awakens  2015
# 5                         Avengers: Infinity War  2018
#
#       international_revenue_usd
# rank
# 1                    2797800564
# 2                    2790439000
# 3                    2195169138
# 4                    2068223624
# 5                    2048359754

# %%
# Change name column to lower case to easier join 
international_v2['name_international'] = international_v2['name_international'].str.capitalize()

# %%
international_v2.head()
# Out:
#                               name_international  year  \
# rank
# 1                              Avengers: endgame  2019
# 2                                         Avatar  2009
# 3                                        Titanic  1997
# 4     Star wars: episode vii - the force awakens  2015
# 5                         Avengers: infinity war  2018
#
#       international_revenue_usd
# rank
# 1                    2797800564
# 2                    2790439000
# 3                    2195169138
# 4                    2068223624
# 5                    2048359754

# %%
international_v2.to_csv('Resources/Master_table_v3.csv')

# %% [markdown]
# #### Clean domestic revenue data

# %%
domestic_df = pd.read_csv('Resources/datasets_movies_v3.csv')

# %%
domestic_df['name'] = domestic_df['name'].str.capitalize()

# %%
domestic_df = domestic_df.drop(columns=['year','country'])

# %%
domestic_df.head()
# Out:
#      budget                                 company        director  \
# 0   8000000           Columbia Pictures Corporation      Rob Reiner
# 1   6000000                      Paramount Pictures     John Hughes
# 2  15000000                      Paramount Pictures      Tony Scott
# 3  18500000  Twentieth Century Fox Film Corporation   James Cameron
# 4   9000000                    Walt Disney Pictures  Randal Kleiser
#
#        genre      gross                      name rating released  runtime  \
# 0  Adventure   52287414               Stand by me      R  8/22/86       89
# 1     Comedy   70136369  Ferris bueller's day off  PG-13  6/11/86      103
# 2     Action  179800601                   Top gun     PG  5/16/86      110
# 3     Action   85160248                    Aliens      R  7/18/86      137
# 4  Adventure   18564613   Flight of the navigator     PG   8/1/86       90
#
#    score               star   votes         writer
# 0    8.1        Wil Wheaton  299174   Stephen King
# 1    7.8  Matthew Broderick  264740    John Hughes
# 2    6.9         Tom Cruise  236909       Jim Cash
# 3    8.4   Sigourney Weaver  540152  James Cameron
# 4    6.9        Joey Cramer   36636  Mark H. Baker

# %%
# Getting the duplicate movie by title and year released. 
duplicated_domestic_df = domestic_df.loc[domestic_df.duplicated(subset=["name"]), "name"].unique()
duplicated_domestic_df
# Out:
# array(['Dream lover', 'Boiling point', "Nobody's fool", 'Heat',
#        'It takes two', 'Rumpelstiltskin', 'Hamlet', 'Bulletproof',
#        'The cure', 'Gladiator', 'Chocolat', 'Where the heart is',
#        'Saving grace', 'The in crowd', 'Behind enemy lines', 'Out cold',
#        'Pulse', 'Insomnia', 'Hero', 'Bad company', 'Crossroads',
#        'The rookie', 'The hunted', 'It runs in the family',
#        'The phantom of the opera', 'Man on fire', 'Taxi', 'Proof',
#        'The proposition', 'Fever pitch', 'Man of the house', 'Invincible',
#        'The guardian', 'Running scared', 'Fearless', 'Black sheep',
#        'Hairspray', 'Sunshine', 'The hitcher', 'Flawless', 'Twilight',
#        'The eye', 'Mother', 'The stepfather', 'The unborn',
#        "Everybody's fine", 'Trust', 'Fair game', 'Death at a funeral',
#        'Morning glory', 'The girl with the dragon tattoo', 'Priest',
#        'The three musketeers', 'Jane eyre', 'Unknown', 'Trespass',
#        'The avengers', 'Les misèrables', 'Anna karenina', 'Project x',
#        'Safe', 'Deadfall', 'Great expectations', 'Playing for keeps',
#        'Much ado about nothing', 'Promised land', 'Cocktail', 'Frozen',
#        'Rush', 'Beautiful creatures', 'The host', 'Stalingrad',
#        'Hercules', 'Godzilla', 'Robocop', 'Teenage mutant ninja turtles',
#        'Leviathan', 'The gift', 'Fantastic four', 'Concussion',
#        'No escape', 'Hot pursuit', 'Max', 'Sing', 'Passengers', 'Voraz',
#        'Masterminds'], dtype=object)

# %%
# Check duplicated movie
duplicated_domestic_df = domestic_df.loc[domestic_df["name"] == "Dream lover"]
duplicated_domestic_df
# Out:
#       budget                        company        director  genre   gross  \
# 192        0      Metro-Goldwyn-Mayer (MGM)  Alan J. Pakula  Crime  502237
# 1652       0  PolyGram Filmed Entertainment  Nicholas Kazan  Drama  256264
#
#              name rating released  runtime  score             star  votes  \
# 192   Dream lover      R   4/2/86      104    5.1  Kristy McNichol    405
# 1652  Dream lover      R   5/6/94      103    6.2     James Spader   3327
#
#               writer
# 192     Jon Boorstin
# 1652  Nicholas Kazan

# %%
# Drop duplicates and keep first
domestic_revenue_v2 = domestic_df.drop_duplicates(subset=['name'], keep='first')

# %%
domestic_revenue_v2
# Out:
#         budget                                 company         director  \
# 0      8000000           Columbia Pictures Corporation       Rob Reiner
# 1      6000000                      Paramount Pictures      John Hughes
# 2     15000000                      Paramount Pictures       Tony Scott
# 3     18500000  Twentieth Century Fox Film Corporation    James Cameron
# 4      9000000                    Walt Disney Pictures   Randal Kleiser
# ...        ...                                     ...              ...
# 6815         0                Fox Searchlight Pictures  Mandie Fletcher
# 6816         0                Siempre Viva Productions   Paul Duddridge
# 6817   3500000                  Warner Bros. Animation          Sam Liu
# 6818         0                     Borderline Presents    Nicolas Pesce
# 6819         0               Les Productions du TrÈsor    Nicole Garcia
#
#           genre      gross                            name rating released  \
# 0     Adventure   52287414                     Stand by me      R  8/22/86
# 1        Comedy   70136369        Ferris bueller's day off  PG-13  6/11/86
# 2        Action  179800601                         Top gun     PG  5/16/86
# 3        Action   85160248                          Aliens      R  7/18/86
# 4     Adventure   18564613         Flight of the navigator     PG   8/1/86
# ...         ...        ...                             ...    ...      ...
# 6815     Comedy    4750497  Absolutely fabulous: the movie      R  7/22/16
# 6816      Drama      28368           Mothers and daughters  PG-13   5/6/16
# 6817  Animation    3775000        Batman: the killing joke      R  7/25/16
# 6818      Drama      25981           The eyes of my mother      R  12/2/16
# 6819      Drama      37757       From the land of the moon      R  7/28/17
#
#       runtime  score               star   votes             writer
# 0          89    8.1        Wil Wheaton  299174       Stephen King
# 1         103    7.8  Matthew Broderick  264740        John Hughes
# 2         110    6.9         Tom Cruise  236909           Jim Cash
# 3         137    8.4   Sigourney Weaver  540152      James Cameron
# 4          90    6.9        Joey Cramer   36636      Mark H. Baker
# ...       ...    ...                ...     ...                ...
# 6815       91    5.4  Jennifer Saunders    9161  Jennifer Saunders
# 6816       90    4.9        Selma Blair    1959      Paige Cameron
# 6817       76    6.5       Kevin Conroy   36333    Brian Azzarello
# 6818       76    6.2     Kika Magalh„es    6947      Nicolas Pesce
# 6819      120    6.7   Marion Cotillard    2411        Milena Agus
#
# [6731 rows x 13 columns]

# %%
len(domestic_revenue_v2)
# Out:
# 6731

# %%
duplicated_dom_df = domestic_revenue_v2.loc[domestic_revenue_v2.duplicated(subset=["name"]), "name"].unique()

# %%
domestic_revenue_v2 = domestic_revenue_v2.rename(columns={'gross': 'domestic_revenue_usd',
                                                         'name': 'name_domestic'})

# %%
domestic_revenue_v2
# Out:
#         budget                                 company         director  \
# 0      8000000           Columbia Pictures Corporation       Rob Reiner
# 1      6000000                      Paramount Pictures      John Hughes
# 2     15000000                      Paramount Pictures       Tony Scott
# 3     18500000  Twentieth Century Fox Film Corporation    James Cameron
# 4      9000000                    Walt Disney Pictures   Randal Kleiser
# ...        ...                                     ...              ...
# 6815         0                Fox Searchlight Pictures  Mandie Fletcher
# 6816         0                Siempre Viva Productions   Paul Duddridge
# 6817   3500000                  Warner Bros. Animation          Sam Liu
# 6818         0                     Borderline Presents    Nicolas Pesce
# 6819         0               Les Productions du TrÈsor    Nicole Garcia
#
#           genre  domestic_revenue_usd                   name_domestic rating  \
# 0     Adventure              52287414                     Stand by me      R
# 1        Comedy              70136369        Ferris bueller's day off  PG-13
# 2        Action             179800601                         Top gun     PG
# 3        Action              85160248                          Aliens      R
# 4     Adventure              18564613         Flight of the navigator     PG
# ...         ...                   ...                             ...    ...
# 6815     Comedy               4750497  Absolutely fabulous: the movie      R
# 6816      Drama                 28368           Mothers and daughters  PG-13
# 6817  Animation               3775000        Batman: the killing joke      R
# 6818      Drama                 25981           The eyes of my mother      R
# 6819      Drama                 37757       From the land of the moon      R
#
#      released  runtime  score               star   votes             writer
# 0     8/22/86       89    8.1        Wil Wheaton  299174       Stephen King
# 1     6/11/86      103    7.8  Matthew Broderick  264740        John Hughes
# 2     5/16/86      110    6.9         Tom Cruise  236909           Jim Cash
# 3     7/18/86      137    8.4   Sigourney Weaver  540152      James Cameron
# 4      8/1/86       90    6.9        Joey Cramer   36636      Mark H. Baker
# ...       ...      ...    ...                ...     ...                ...
# 6815  7/22/16       91    5.4  Jennifer Saunders    9161  Jennifer Saunders
# 6816   5/6/16       90    4.9        Selma Blair    1959      Paige Cameron
# 6817  7/25/16       76    6.5       Kevin Conroy   36333    Brian Azzarello
# 6818  12/2/16       76    6.2     Kika Magalh„es    6947      Nicolas Pesce
# 6819  7/28/17      120    6.7   Marion Cotillard    2411        Milena Agus
#
# [6731 rows x 13 columns]

# %%
domestic_revenue_v2.to_csv('Resources/Domestic_v3.csv')

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %% [markdown]
# ### Mac (Irina) Connection

# %%
# # https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver

# %%
# executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Windows (Clay) Connection

# %%
# executable_path = {'executable_path': 'C:/Users/Clay/chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Connect to local database

# %%
connection_string = f'{username}:{password}@localhost:5432/movies_db'
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['international_revenue', 'best_200_directors']

# %%
# Create international revenue table in the database
international_v2.to_sql(name='international_revenue', con=engine, if_exists='append', index=False)

# %%
# Create domesic revenue table in the database
domestic_revenue_v2.to_sql(name='domestic_revenue', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['international_revenue', 'best_200_directors', 'domestic_revenue']

# %% [markdown]
# ### Confirm data has been added by querying the international table

# %%
pd.read_sql_query("select * from international_revenue", con=engine).head()
# Out:
#                            name_international  year  international_revenue_usd
# 0                           Avengers: endgame  2019                 2797800564
# 1                                      Avatar  2009                 2790439000
# 2                                     Titanic  1997                 2195169138
# 3  Star wars: episode vii - the force awakens  2015                 2068223624
# 4                      Avengers: infinity war  2018                 2048359754

# %%
pd.read_sql_query('select * from domestic_revenue', con=engine).head()
# Out:
#      budget                                 company        director  \
# 0   8000000           Columbia Pictures Corporation      Rob Reiner
# 1   6000000                      Paramount Pictures     John Hughes
# 2  15000000                      Paramount Pictures      Tony Scott
# 3  18500000  Twentieth Century Fox Film Corporation   James Cameron
# 4   9000000                    Walt Disney Pictures  Randal Kleiser
#
#        genre  domestic_revenue_usd             name_domestic rating released  \
# 0  Adventure              52287414               Stand by me      R  8/22/86
# 1     Comedy              70136369  Ferris bueller's day off  PG-13  6/11/86
# 2     Action             179800601                   Top gun     PG  5/16/86
# 3     Action              85160248                    Aliens      R  7/18/86
# 4  Adventure              18564613   Flight of the navigator     PG   8/1/86
#
#    runtime  score               star   votes         writer
# 0       89    8.1        Wil Wheaton  299174   Stephen King
# 1      103    7.8  Matthew Broderick  264740    John Hughes
# 2      110    6.9         Tom Cruise  236909       Jim Cash
# 3      137    8.4   Sigourney Weaver  540152  James Cameron
# 4       90    6.9        Joey Cramer   36636  Mark H. Baker

# %% [markdown]
# ### Best movie directors of all times

# %%
best_director_url  = 'https://www.imdb.com/list/ls056848274/'
best_director_url2 = 'https://www.imdb.com/list/ls056848274/?sort=list_order,asc&mode=detail&page=2'

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
browser.visit(best_director_url)
# time.sleep(5)

# %%
results = browser.find_by_css("h3")
results

# %%
list_original = []
for i in results:
    print(i.text)
    list_original.append(i.text)
# Out:
# 1. Steven Spielberg
# 2. Martin Scorsese
# 3. Alfred Hitchcock
# 4. Stanley Kubrick
# 5. Quentin Tarantino
# 6. Orson Welles
# 7. Francis Ford Coppola
# 8. Ridley Scott
# 9. Akira Kurosawa
# 10. Joel Coen
# 11. Ethan Coen
# 12. John Ford
# 13. Sergio Leone
# 14. Woody Allen
# 15. Billy Wilder
# 16. Clint Eastwood
# 17. Frank Capra
# 18. Charles Chaplin
# 19. Christopher Nolan
# 20. Roman Polanski
# 21. Ingmar Bergman
# 22. David Lynch
# 23. Fritz Lang
# 24. David Fincher
# 25. Peter Jackson
# 26. Federico Fellini
# 27. Tim Burton
# 28. James Cameron
# 29. Sidney Lumet
# 30. Brian De Palma
# 31. François Truffaut
# 32. Terrence Malick
# 33. David Cronenberg
# 34. William Wyler
# 35. Robert Zemeckis
# 36. Ang Lee
# 37. Howard Hawks
# 38. George Lucas
# 39. Mel Brooks
# 40. Terry Gilliam
# 41. Milos Forman
# 42. Steven Soderbergh
# 43. John Huston
# 44. Werner Herzog
# 45. Oliver Stone
# 46. David Lean
# 47. Danny Boyle
# 48. Rob Reiner
# 49. Buster Keaton
# 50. Michael Curtiz
# 51. Sam Raimi
# 52. Michael Mann
# 53. Robert Altman
# 54. Sam Peckinpah
# 55. Peter Weir
# 56. Spike Lee
# 57. Jean Renoir
# 58. Andrei Tarkovsky
# 59. Elia Kazan
# 60. John Cassavetes
# 61. Vincente Minnelli
# 62. Hayao Miyazaki
# 63. Frank Darabont
# 64. Kathryn Bigelow
# 65. George Cukor
# 66. Ron Howard
# 67. John Carpenter
# 68. Guy Ritchie
# 69. Tony Scott
# 70. Gus Van Sant
# 71. Preston Sturges
# 72. Sergei M. Eisenstein
# 73. David O. Russell
# 74. John Frankenheimer
# 75. Blake Edwards
# 76. Ernst Lubitsch
# 77. Jonathan Demme
# 78. Alejandro G. Iñárritu
# 79. Sam Mendes
# 80. Guillermo del Toro
# 81. Joseph L. Mankiewicz
# 82. Satyajit Ray
# 83. Paul Thomas Anderson
# 84. Wes Anderson
# 85. Alfonso Cuarón
# 86. Paul Verhoeven
# 87. F.W. Murnau
# 88. Robert Wise
# 89. Franco Zeffirelli
# 90. Paul Greengrass
# 91. F.W. Murnau
# 92. Don Siegel
# 93. Vittorio De Sica
# 94. John Hughes
# 95. Robert Rodriguez
# 96. Zack Snyder
# 97. Mel Gibson
# 98. Luis Buñuel
# 99. Greta Gerwig
# 100. Krzysztof Kieslowski
# List Activity
# Tell Your Friends
# Other Lists by ketedy
# Recently Viewed

# %%
directors_list_100 = list_original[:100]
directors_list_100
# Out:
# ['1. Steven Spielberg',
#  '2. Martin Scorsese',
#  '3. Alfred Hitchcock',
#  '4. Stanley Kubrick',
#  '5. Quentin Tarantino',
#  '6. Orson Welles',
#  '7. Francis Ford Coppola',
#  '8. Ridley Scott',
#  '9. Akira Kurosawa',
#  '10. Joel Coen',
#  '11. Ethan Coen',
#  '12. John Ford',
#  '13. Sergio Leone',
#  '14. Woody Allen',
#  '15. Billy Wilder',
#  '16. Clint Eastwood',
#  '17. Frank Capra',
#  '18. Charles Chaplin',
#  '19. Christopher Nolan',
#  '20. Roman Polanski',
#  '21. Ingmar Bergman',
#  '22. David Lynch',
#  '23. Fritz Lang',
#  '24. David Fincher',
#  '25. Peter Jackson',
#  '26. Federico Fellini',
#  '27. Tim Burton',
#  '28. James Cameron',
#  '29. Sidney Lumet',
#  '30. Brian De Palma',
#  '31. François Truffaut',
#  '32. Terrence Malick',
#  '33. David Cronenberg',
#  '34. William Wyler',
#  '35. Robert Zemeckis',
#  '36. Ang Lee',
#  '37. Howard Hawks',
#  '38. George Lucas',
#  '39. Mel Brooks',
#  '40. Terry Gilliam',
#  '41. Milos Forman',
#  '42. Steven Soderbergh',
#  '43. John Huston',
#  '44. Werner Herzog',
#  '45. Oliver Stone',
#  '46. David Lean',
#  '47. Danny Boyle',
#  '48. Rob Reiner',
#  '49. Buster Keaton',
#  '50. Michael Curtiz',
#  '51. Sam Raimi',
#  '52. Michael Mann',
#  '53. Robert Altman',
#  '54. Sam Peckinpah',
#  '55. Peter Weir',
#  '56. Spike Lee',
#  '57. Jean Renoir',
#  '58. Andrei Tarkovsky',
#  '59. Elia Kazan',
#  '60. John Cassavetes',
#  '61. Vincente Minnelli',
#  '62. Hayao Miyazaki',
#  '63. Frank Darabont',
#  '64. Kathryn Bigelow',
#  '65. George Cukor',
#  '66. Ron Howard',
#  '67. John Carpenter',
#  '68. Guy Ritchie',
#  '69. Tony Scott',
#  '70. Gus Van Sant',
#  '71. Preston Sturges',
#  '72. Sergei M. Eisenstein',
#  '73. David O. Russell',
#  '74. John Frankenheimer',
#  '75. Blake Edwards',
#  '76. Ernst Lubitsch',
#  '77. Jonathan Demme',
#  '78. Alejandro G. Iñárritu',
#  '79. Sam Mendes',
#  '80. Guillermo del Toro',
#  '81. Joseph L. Mankiewicz',
#  '82. Satyajit Ray',
#  '83. Paul Thomas Anderson',
#  '84. Wes Anderson',
#  '85. Alfonso Cuarón',
#  '86. Paul Verhoeven',
#  '87. F.W. Murnau',
#  '88. Robert Wise',
#  '89. Franco Zeffirelli',
#  '90. Paul Greengrass',
#  '91. F.W. Murnau',
#  '92. Don Siegel',
#  '93. Vittorio De Sica',
#  '94. John Hughes',
#  '95. Robert Rodriguez',
#  '96. Zack Snyder',
#  '97. Mel Gibson',
#  '98. Luis Buñuel',
#  '99. Greta Gerwig',
#  '100. Krzysztof Kieslowski']

# %%
clean_list1 = []
for i in directors_list_100:
    director = i.split('. ')[-1]
    print(director)
    clean_list1.append(director)
# Out:
# Steven Spielberg
# Martin Scorsese
# Alfred Hitchcock
# Stanley Kubrick
# Quentin Tarantino
# Orson Welles
# Francis Ford Coppola
# Ridley Scott
# Akira Kurosawa
# Joel Coen
# Ethan Coen
# John Ford
# Sergio Leone
# Woody Allen
# Billy Wilder
# Clint Eastwood
# Frank Capra
# Charles Chaplin
# Christopher Nolan
# Roman Polanski
# Ingmar Bergman
# David Lynch
# Fritz Lang
# David Fincher
# Peter Jackson
# Federico Fellini
# Tim Burton
# James Cameron
# Sidney Lumet
# Brian De Palma
# François Truffaut
# Terrence Malick
# David Cronenberg
# William Wyler
# Robert Zemeckis
# Ang Lee
# Howard Hawks
# George Lucas
# Mel Brooks
# Terry Gilliam
# Milos Forman
# Steven Soderbergh
# John Huston
# Werner Herzog
# Oliver Stone
# David Lean
# Danny Boyle
# Rob Reiner
# Buster Keaton
# Michael Curtiz
# Sam Raimi
# Michael Mann
# Robert Altman
# Sam Peckinpah
# Peter Weir
# Spike Lee
# Jean Renoir
# Andrei Tarkovsky
# Elia Kazan
# John Cassavetes
# Vincente Minnelli
# Hayao Miyazaki
# Frank Darabont
# Kathryn Bigelow
# George Cukor
# Ron Howard
# John Carpenter
# Guy Ritchie
# Tony Scott
# Gus Van Sant
# Preston Sturges
# Eisenstein
# Russell
# John Frankenheimer
# Blake Edwards
# Ernst Lubitsch
# Jonathan Demme
# Iñárritu
# Sam Mendes
# Guillermo del Toro
# Mankiewicz
# Satyajit Ray
# Paul Thomas Anderson
# Wes Anderson
# Alfonso Cuarón
# Paul Verhoeven
# Murnau
# Robert Wise
# Franco Zeffirelli
# Paul Greengrass
# Murnau
# Don Siegel
# Vittorio De Sica
# John Hughes
# Robert Rodriguez
# Zack Snyder
# Mel Gibson
# Luis Buñuel
# Greta Gerwig
# Krzysztof Kieslowski

# %%
clean_list1
# Out:
# ['Steven Spielberg',
#  'Martin Scorsese',
#  'Alfred Hitchcock',
#  'Stanley Kubrick',
#  'Quentin Tarantino',
#  'Orson Welles',
#  'Francis Ford Coppola',
#  'Ridley Scott',
#  'Akira Kurosawa',
#  'Joel Coen',
#  'Ethan Coen',
#  'John Ford',
#  'Sergio Leone',
#  'Woody Allen',
#  'Billy Wilder',
#  'Clint Eastwood',
#  'Frank Capra',
#  'Charles Chaplin',
#  'Christopher Nolan',
#  'Roman Polanski',
#  'Ingmar Bergman',
#  'David Lynch',
#  'Fritz Lang',
#  'David Fincher',
#  'Peter Jackson',
#  'Federico Fellini',
#  'Tim Burton',
#  'James Cameron',
#  'Sidney Lumet',
#  'Brian De Palma',
#  'François Truffaut',
#  'Terrence Malick',
#  'David Cronenberg',
#  'William Wyler',
#  'Robert Zemeckis',
#  'Ang Lee',
#  'Howard Hawks',
#  'George Lucas',
#  'Mel Brooks',
#  'Terry Gilliam',
#  'Milos Forman',
#  'Steven Soderbergh',
#  'John Huston',
#  'Werner Herzog',
#  'Oliver Stone',
#  'David Lean',
#  'Danny Boyle',
#  'Rob Reiner',
#  'Buster Keaton',
#  'Michael Curtiz',
#  'Sam Raimi',
#  'Michael Mann',
#  'Robert Altman',
#  'Sam Peckinpah',
#  'Peter Weir',
#  'Spike Lee',
#  'Jean Renoir',
#  'Andrei Tarkovsky',
#  'Elia Kazan',
#  'John Cassavetes',
#  'Vincente Minnelli',
#  'Hayao Miyazaki',
#  'Frank Darabont',
#  'Kathryn Bigelow',
#  'George Cukor',
#  'Ron Howard',
#  'John Carpenter',
#  'Guy Ritchie',
#  'Tony Scott',
#  'Gus Van Sant',
#  'Preston Sturges',
#  'Eisenstein',
#  'Russell',
#  'John Frankenheimer',
#  'Blake Edwards',
#  'Ernst Lubitsch',
#  'Jonathan Demme',
#  'Iñárritu',
#  'Sam Mendes',
#  'Guillermo del Toro',
#  'Mankiewicz',
#  'Satyajit Ray',
#  'Paul Thomas Anderson',
#  'Wes Anderson',
#  'Alfonso Cuarón',
#  'Paul Verhoeven',
#  'Murnau',
#  'Robert Wise',
#  'Franco Zeffirelli',
#  'Paul Greengrass',
#  'Murnau',
#  'Don Siegel',
#  'Vittorio De Sica',
#  'John Hughes',
#  'Robert Rodriguez',
#  'Zack Snyder',
#  'Mel Gibson',
#  'Luis Buñuel',
#  'Greta Gerwig',
#  'Krzysztof Kieslowski']

# %%
browser.visit(best_director_url2)
# time.sleep(5)

# %%
results2 = browser.find_by_css("h3")
results2

# %%
original_list2 = []
for i in results2:
#     print(i.text)
    original_list2.append(i.text)

# %%
directors_list2 = original_list2[:100]
directors_list2
# Out:
# ['101. Jean-Luc Godard',
#  '102. Tom Hooper',
#  '103. William Friedkin',
#  '104. Antoine Fuqua',
#  '105. Sydney Pollack',
#  '106. Bernardo Bertolucci',
#  '107. John Lasseter',
#  '108. David Ayer',
#  '109. J.J. Abrams',
#  '110. Mike Nichols',
#  '111. Lars von Trier',
#  '112. John Milius',
#  '113. John McTiernan',
#  '114. Costa-Gavras',
#  '115. Cecil B. DeMille',
#  '116. Darren Aronofsky',
#  '117. Luc Besson',
#  '118. Doug Liman',
#  '119. Bryan Singer',
#  '120. Richard Linklater',
#  '121. Anthony Minghella',
#  '122. Curtis Hanson',
#  '123. Michael Haneke',
#  '124. D.W. Griffith',
#  '125. Alan Parker',
#  '126. Edgar Wright',
#  '127. Pedro Almodóvar',
#  '128. Barry Levinson',
#  '129. Michelangelo Antonioni',
#  '130. Cameron Crowe',
#  '131. Jim Jarmusch',
#  '132. Vittorio De Sica',
#  '133. Spike Jonze',
#  '134. Harold Ramis',
#  '135. Michael Moore',
#  '136. Shane Meadows',
#  '137. Ken Loach',
#  '138. Bobby Farrelly',
#  '139. Jacques Audiard',
#  '140. Gore Verbinski',
#  '141. Jay Roach',
#  '142. Jim Sheridan',
#  '143. John Landis',
#  '144. Richard Donner',
#  '145. Jason Reitman',
#  '146. Robert Redford',
#  '147. Andrew Dominik',
#  '148. Joss Whedon',
#  '149. George Miller',
#  '150. David Zucker',
#  '151. George A. Romero',
#  '152. Mike Leigh',
#  '153. David O. Russell',
#  '154. Neil Jordan',
#  '155. Wilfred Jackson',
#  '156. Alan J. Pakula',
#  '157. George Roy Hill',
#  '158. Michael Powell',
#  '159. Richard Donner',
#  '160. John Woo',
#  '161. Sofia Coppola',
#  '162. Sofia Coppola',
#  '163. Takashi Miike',
#  '164. Brad Bird',
#  '165. Alex Gibney',
#  '166. Bob Foss',
#  '167. Carol Reed',
#  '168. Christopher Guest',
#  '169. Otto Preminger',
#  '170. Peter Bogdanovich',
#  '171. David Yates',
#  '172. Wes Craven',
#  '173. Kevin Smith',
#  '174. Fred Zinnemann',
#  '175. Ava DuVernay',
#  '176. Jean-Pierre Jeunet',
#  '177. George Stevens',
#  '178. Frank Lloyd',
#  '179. Wim Wenders',
#  '180. Georges Méliès',
#  '181. Wolfgang Petersen',
#  '182. Leo McCarey',
#  '183. Lewis Milestone',
#  '184. Éric Rohmer',
#  '185. Lilly Wachowski',
#  '186. Neill Blomkamp',
#  '187. Warren Beatty',
#  '188. Pier Paolo Pasolini',
#  '189. Kar-Wai Wong',
#  '190. Robert Bresson',
#  '191. Emir Kusturica',
#  '192. Yasujirô Ozu',
#  '193. John Lasseter',
#  '194. Michael Haneke',
#  '195. Takeshi Kitano',
#  '196. Theodoros Angelopoulos',
#  '197. James Whale',
#  '198. Terence Fisher',
#  '199. Chuck Jones',
#  '200. Luchino Visconti']

# %%
clean_list2 = []
for i in directors_list2:
    director = i.split('. ')[-1]
    clean_list2.append(director)

# %%
clean_list2
# Out:
# ['Jean-Luc Godard',
#  'Tom Hooper',
#  'William Friedkin',
#  'Antoine Fuqua',
#  'Sydney Pollack',
#  'Bernardo Bertolucci',
#  'John Lasseter',
#  'David Ayer',
#  'Abrams',
#  'Mike Nichols',
#  'Lars von Trier',
#  'John Milius',
#  'John McTiernan',
#  'Costa-Gavras',
#  'DeMille',
#  'Darren Aronofsky',
#  'Luc Besson',
#  'Doug Liman',
#  'Bryan Singer',
#  'Richard Linklater',
#  'Anthony Minghella',
#  'Curtis Hanson',
#  'Michael Haneke',
#  'Griffith',
#  'Alan Parker',
#  'Edgar Wright',
#  'Pedro Almodóvar',
#  'Barry Levinson',
#  'Michelangelo Antonioni',
#  'Cameron Crowe',
#  'Jim Jarmusch',
#  'Vittorio De Sica',
#  'Spike Jonze',
#  'Harold Ramis',
#  'Michael Moore',
#  'Shane Meadows',
#  'Ken Loach',
#  'Bobby Farrelly',
#  'Jacques Audiard',
#  'Gore Verbinski',
#  'Jay Roach',
#  'Jim Sheridan',
#  'John Landis',
#  'Richard Donner',
#  'Jason Reitman',
#  'Robert Redford',
#  'Andrew Dominik',
#  'Joss Whedon',
#  'George Miller',
#  'David Zucker',
#  'Romero',
#  'Mike Leigh',
#  'Russell',
#  'Neil Jordan',
#  'Wilfred Jackson',
#  'Pakula',
#  'George Roy Hill',
#  'Michael Powell',
#  'Richard Donner',
#  'John Woo',
#  'Sofia Coppola',
#  'Sofia Coppola',
#  'Takashi Miike',
#  'Brad Bird',
#  'Alex Gibney',
#  'Bob Foss',
#  'Carol Reed',
#  'Christopher Guest',
#  'Otto Preminger',
#  'Peter Bogdanovich',
#  'David Yates',
#  'Wes Craven',
#  'Kevin Smith',
#  'Fred Zinnemann',
#  'Ava DuVernay',
#  'Jean-Pierre Jeunet',
#  'George Stevens',
#  'Frank Lloyd',
#  'Wim Wenders',
#  'Georges Méliès',
#  'Wolfgang Petersen',
#  'Leo McCarey',
#  'Lewis Milestone',
#  'Éric Rohmer',
#  'Lilly Wachowski',
#  'Neill Blomkamp',
#  'Warren Beatty',
#  'Pier Paolo Pasolini',
#  'Kar-Wai Wong',
#  'Robert Bresson',
#  'Emir Kusturica',
#  'Yasujirô Ozu',
#  'John Lasseter',
#  'Michael Haneke',
#  'Takeshi Kitano',
#  'Theodoros Angelopoulos',
#  'James Whale',
#  'Terence Fisher',
#  'Chuck Jones',
#  'Luchino Visconti']

# %%
directors = clean_list1 + clean_list2
directors
# Out:
# ['Steven Spielberg',
#  'Martin Scorsese',
#  'Alfred Hitchcock',
#  'Stanley Kubrick',
#  'Quentin Tarantino',
#  'Orson Welles',
#  'Francis Ford Coppola',
#  'Ridley Scott',
#  'Akira Kurosawa',
#  'Joel Coen',
#  'Ethan Coen',
#  'John Ford',
#  'Sergio Leone',
#  'Woody Allen',
#  'Billy Wilder',
#  'Clint Eastwood',
#  'Frank Capra',
#  'Charles Chaplin',
#  'Christopher Nolan',
#  'Roman Polanski',
#  'Ingmar Bergman',
#  'David Lynch',
#  'Fritz Lang',
#  'David Fincher',
#  'Peter Jackson',
#  'Federico Fellini',
#  'Tim Burton',
#  'James Cameron',
#  'Sidney Lumet',
#  'Brian De Palma',
#  'François Truffaut',
#  'Terrence Malick',
#  'David Cronenberg',
#  'William Wyler',
#  'Robert Zemeckis',
#  'Ang Lee',
#  'Howard Hawks',
#  'George Lucas',
#  'Mel Brooks',
#  'Terry Gilliam',
#  'Milos Forman',
#  'Steven Soderbergh',
#  'John Huston',
#  'Werner Herzog',
#  'Oliver Stone',
#  'David Lean',
#  'Danny Boyle',
#  'Rob Reiner',
#  'Buster Keaton',
#  'Michael Curtiz',
#  'Sam Raimi',
#  'Michael Mann',
#  'Robert Altman',
#  'Sam Peckinpah',
#  'Peter Weir',
#  'Spike Lee',
#  'Jean Renoir',
#  'Andrei Tarkovsky',
#  'Elia Kazan',
#  'John Cassavetes',
#  'Vincente Minnelli',
#  'Hayao Miyazaki',
#  'Frank Darabont',
#  'Kathryn Bigelow',
#  'George Cukor',
#  'Ron Howard',
#  'John Carpenter',
#  'Guy Ritchie',
#  'Tony Scott',
#  'Gus Van Sant',
#  'Preston Sturges',
#  'Eisenstein',
#  'Russell',
#  'John Frankenheimer',
#  'Blake Edwards',
#  'Ernst Lubitsch',
#  'Jonathan Demme',
#  'Iñárritu',
#  'Sam Mendes',
#  'Guillermo del Toro',
#  'Mankiewicz',
#  'Satyajit Ray',
#  'Paul Thomas Anderson',
#  'Wes Anderson',
#  'Alfonso Cuarón',
#  'Paul Verhoeven',
#  'Murnau',
#  'Robert Wise',
#  'Franco Zeffirelli',
#  'Paul Greengrass',
#  'Murnau',
#  'Don Siegel',
#  'Vittorio De Sica',
#  'John Hughes',
#  'Robert Rodriguez',
#  'Zack Snyder',
#  'Mel Gibson',
#  'Luis Buñuel',
#  'Greta Gerwig',
#  'Krzysztof Kieslowski',
#  'Jean-Luc Godard',
#  'Tom Hooper',
#  'William Friedkin',
#  'Antoine Fuqua',
#  'Sydney Pollack',
#  'Bernardo Bertolucci',
#  'John Lasseter',
#  'David Ayer',
#  'Abrams',
#  'Mike Nichols',
#  'Lars von Trier',
#  'John Milius',
#  'John McTiernan',
#  'Costa-Gavras',
#  'DeMille',
#  'Darren Aronofsky',
#  'Luc Besson',
#  'Doug Liman',
#  'Bryan Singer',
#  'Richard Linklater',
#  'Anthony Minghella',
#  'Curtis Hanson',
#  'Michael Haneke',
#  'Griffith',
#  'Alan Parker',
#  'Edgar Wright',
#  'Pedro Almodóvar',
#  'Barry Levinson',
#  'Michelangelo Antonioni',
#  'Cameron Crowe',
#  'Jim Jarmusch',
#  'Vittorio De Sica',
#  'Spike Jonze',
#  'Harold Ramis',
#  'Michael Moore',
#  'Shane Meadows',
#  'Ken Loach',
#  'Bobby Farrelly',
#  'Jacques Audiard',
#  'Gore Verbinski',
#  'Jay Roach',
#  'Jim Sheridan',
#  'John Landis',
#  'Richard Donner',
#  'Jason Reitman',
#  'Robert Redford',
#  'Andrew Dominik',
#  'Joss Whedon',
#  'George Miller',
#  'David Zucker',
#  'Romero',
#  'Mike Leigh',
#  'Russell',
#  'Neil Jordan',
#  'Wilfred Jackson',
#  'Pakula',
#  'George Roy Hill',
#  'Michael Powell',
#  'Richard Donner',
#  'John Woo',
#  'Sofia Coppola',
#  'Sofia Coppola',
#  'Takashi Miike',
#  'Brad Bird',
#  'Alex Gibney',
#  'Bob Foss',
#  'Carol Reed',
#  'Christopher Guest',
#  'Otto Preminger',
#  'Peter Bogdanovich',
#  'David Yates',
#  'Wes Craven',
#  'Kevin Smith',
#  'Fred Zinnemann',
#  'Ava DuVernay',
#  'Jean-Pierre Jeunet',
#  'George Stevens',
#  'Frank Lloyd',
#  'Wim Wenders',
#  'Georges Méliès',
#  'Wolfgang Petersen',
#  'Leo McCarey',
#  'Lewis Milestone',
#  'Éric Rohmer',
#  'Lilly Wachowski',
#  'Neill Blomkamp',
#  'Warren Beatty',
#  'Pier Paolo Pasolini',
#  'Kar-Wai Wong',
#  'Robert Bresson',
#  'Emir Kusturica',
#  'Yasujirô Ozu',
#  'John Lasseter',
#  'Michael Haneke',
#  'Takeshi Kitano',
#  'Theodoros Angelopoulos',
#  'James Whale',
#  'Terence Fisher',
#  'Chuck Jones',
#  'Luchino Visconti']

# %%
len(directors)
# Out:
# 200

# %%
directors_df = pd.DataFrame(directors)

# %%
len(directors_df)
# Out:
# 200

# %%
# # Shift the index to start from 1 as the list is ranked
# directors_df = directors_df.shift()[1:]

# %%
# Rename the column
directors_df.rename(columns={0: 'directors'}, inplace=True)

# %%
directors_df.reset_index()
# Out:
#      index               directors
# 0        0        Steven Spielberg
# 1        1         Martin Scorsese
# 2        2        Alfred Hitchcock
# 3        3         Stanley Kubrick
# 4        4       Quentin Tarantino
# ..     ...                     ...
# 195    195  Theodoros Angelopoulos
# 196    196             James Whale
# 197    197          Terence Fisher
# 198    198             Chuck Jones
# 199    199        Luchino Visconti
#
# [200 rows x 2 columns]

# %%
# Save directors to csv
directors_df.to_csv('Resources/Best_directors_200.csv')

# %%
len(directors_df)
# Out:
# 200

# %% [markdown]
# #### Push Directors table to sql

# %%
directors_df.to_sql(name='best_200_directors', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from best_200_directors', con=engine).head()
# Out:
#            directors
# 0   Steven Spielberg
# 1    Martin Scorsese
# 2   Alfred Hitchcock
# 3    Stanley Kubrick
# 4  Quentin Tarantino

# %%
engine.table_names()
# Out:
# ['international_v2', 'domestic_revenue_v2', 'best_200_directors']

# %% [markdown]
# #### Get director's name with the featured movie

# %%
results = browser.find_by_css("span.ghost")

# %%
results

# %%
len(results)
# Out:
# 103

# %%
for i in results:
    print(i.childNodes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-87ca0dd2ece8> in <module>
#       1 for i in results:
# ----> 2     print(i.childNodes)
#
# AttributeError: 'WebDriverElement' object has no attribute 'childNodes'

# %%
list_original = []
for i in results:
    print(i.text)
    list_original.append(i.text)
# Out:
# 1. Steven Spielberg
# 2. Martin Scorsese
# 3. Alfred Hitchcock
# 4. Stanley Kubrick
# 5. Quentin Tarantino
# 6. Orson Welles
# 7. Francis Ford Coppola
# 8. Ridley Scott
# 9. Akira Kurosawa
# 10. Joel Coen
# 11. Ethan Coen
# 12. John Ford
# 13. Sergio Leone
# 14. Woody Allen
# 15. Billy Wilder
# 16. Clint Eastwood
# 17. Frank Capra
# 18. Charles Chaplin
# 19. Christopher Nolan
# 20. Roman Polanski
# 21. Ingmar Bergman
# 22. David Lynch
# 23. Fritz Lang
# 24. David Fincher
# 25. Peter Jackson
# 26. Federico Fellini
# 27. Tim Burton
# 28. James Cameron
# 29. Sidney Lumet
# 30. Brian De Palma
# 31. François Truffaut
# 32. Terrence Malick
# 33. David Cronenberg
# 34. William Wyler
# 35. Robert Zemeckis
# 36. Ang Lee
# 37. Howard Hawks
# 38. George Lucas
# 39. Mel Brooks
# 40. Terry Gilliam
# 41. Milos Forman
# 42. Steven Soderbergh
# 43. John Huston
# 44. Werner Herzog
# 45. Oliver Stone
# 46. David Lean
# 47. Danny Boyle
# 48. Rob Reiner
# 49. Buster Keaton
# 50. Michael Curtiz
# 51. Sam Raimi
# 52. Michael Mann
# 53. Robert Altman
# 54. Sam Peckinpah
# 55. Peter Weir
# 56. Spike Lee
# 57. Jean Renoir
# 58. Andrei Tarkovsky
# 59. Elia Kazan
# 60. John Cassavetes
# 61. Vincente Minnelli
# 62. Hayao Miyazaki
# 63. Frank Darabont
# 64. Kathryn Bigelow
# 65. George Cukor
# 66. Ron Howard
# 67. John Carpenter
# 68. Guy Ritchie
# 69. Tony Scott
# 70. Gus Van Sant
# 71. Preston Sturges
# 72. Sergei M. Eisenstein
# 73. David O. Russell
# 74. John Frankenheimer
# 75. Blake Edwards
# 76. Ernst Lubitsch
# 77. Jonathan Demme
# 78. Alejandro G. Iñárritu
# 79. Sam Mendes
# 80. Guillermo del Toro
# 81. Joseph L. Mankiewicz
# 82. Satyajit Ray
# 83. Paul Thomas Anderson
# 84. Wes Anderson
# 85. Alfonso Cuarón
# 86. Paul Verhoeven
# 87. F.W. Murnau
# 88. Robert Wise
# 89. Franco Zeffirelli
# 90. Paul Greengrass
# 91. F.W. Murnau
# 92. Don Siegel
# 93. Vittorio De Sica
# 94. John Hughes
# 95. Robert Rodriguez
# 96. Zack Snyder
# 97. Mel Gibson
# 98. Luis Buñuel
# 99. Greta Gerwig
# 100. Krzysztof Kieslowski
# List Activity
# Tell Your Friends
# Other Lists by ketedy
# Recently Viewed
